# %%
# Import dependencies
import pandas as pd
import numpy as np
import glob

# %%
# Set path (Change to your file path)
path = r'C:\Users\Michael\Documents\GitHub\final-project\data\basic_index'
all_files = glob.glob(path + "/*.csv")

# list to hold df's
li = []

# For loop to create a df for each csv file
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df = df.fillna(df.mean())
    df = df.round(decimals=2)
    li.append(df)
    
# Concat all csv's into one dataframe
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#              Name  Index Year  Overall Score  Property Rights  \
# 0     Afghanistan        2003          59.61             48.6
# 1         Albania        2003          56.80             30.0
# 2         Algeria        2003          57.70             30.0
# 3          Angola        2003          59.61             48.6
# 4       Argentina        2003          56.30             30.0
# ...           ...         ...            ...              ...
# 3129   Venezuela         2019          25.90              7.6
# 3130      Vietnam        2019          55.30             49.8
# 3131        Yemen        2019          60.77             19.6
# 3132       Zambia        2019          53.60             45.0
# 3133     Zimbabwe        2019          40.40             29.7
#
#       Government Integrity  Judicial Effectiveness  Tax Burden  \
# 0                    39.52                     NaN       71.40
# 1                    10.00                     NaN       83.80
# ...

# %%
# Export to csv
frame.to_csv('data/basic_index/index_concat.csv')
